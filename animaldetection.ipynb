# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: opencv-python==4.11.0.86 in c:\users\ashish\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (4.11.0.86)
# Requirement already satisfied: ultralytics==8.3.70 in c:\users\ashish\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (8.3.70)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ashish\anaconda3\lib\site-packages (from opencv-python==4.11.0.86->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\ashish\anaconda3\lib\site-packages (from ultralytics==8.3.70->-r requirements.txt (line 2)) (3.8.4)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\ashish\anaconda3\lib\site-packages (from ultralytics==8.3.70->-r requirements.txt (line 2)) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\ashish\anaconda3\lib\site-packages (from ultralytics==8.3.70->-r requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\ashish\anaconda3\lib\site-packages (from ultralytics==8.3.70->-r requirements.txt (line 2)) (2.32.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\ashish\anaconda3\lib\site-packages (from ultralytics==8.3.70->-r requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\ashish\anaconda3\lib\site-packages (from ultralytics==8.3.70->-r requirements.txt (line 2)) (2.6.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\ashish\anaconda3\lib\site-packages (from ultralytics==8.3.70->-r requirements.txt (line 2)) (0.21.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\ashish\anaconda3\lib\site-packages (from ultralytics==8.3.70->-r requirements.txt (line 2)) (4.66.4)
# Requirement already satisfied: psutil in c:\users\ashish\anaconda3\lib\site-packages (from ultralytics==8.3.70->-r requirements.txt (line 2)) (5.9.0)
# Requirement already satisfied: py-cpuinfo in c:\users\ashish\anaconda3\lib\site-packages (from ultralytics==8.3.70->-r requirements.txt (line 2)) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\ashish\anaconda3\lib\site-packages (from ultralytics==8.3.70->-r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\ashish\anaconda3\lib\site-packages (from ultralytics==8.3.70->-r requirements.txt (line 2)) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\ashish\anaconda3\lib\site-packages (from ultralytics==8.3.70->-r requirements.txt (line 2)) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ashish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ashish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ashish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ashish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ashish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ashish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ashish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ashish\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics==8.3.70->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ashish\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics==8.3.70->-r requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ashish\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ashish\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ashish\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ashish\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (2024.7.4)
# Requirement already satisfied: filelock in c:\users\ashish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\ashish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (4.11.0)
# Requirement already satisfied: networkx in c:\users\ashish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\ashish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\ashish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (2024.3.1)
# Requirement already satisfied: setuptools in c:\users\ashish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (69.5.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\ashish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ashish\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: colorama in c:\users\ashish\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\ashish\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ashish\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics==8.3.70->-r requirements.txt (line 2)) (2.1.3)

# %%
import cv2
from ultralytics import YOLO

# Load YOLOv8 model trained for object detection
model = YOLO("yolov8n.pt")  # Update with your correct YOLO model path

# Define allowed animal classes (Modify based on the model's class labels)
animal_classes = {'dog', 'cat', 'cow', 'horse', 'sheep', 'elephant', 'zebra', 'giraffe', 'bear', 'deer', 'rabbit', 'fox', 'wolf', 'tiger', 'lion', 'monkey', 'panda'}

# Open webcam (0 = default camera, change if multiple cameras are connected)
cap = cv2.VideoCapture(0)

# Set webcam resolution (optional)
cap.set(3, 640)  # Width
cap.set(4, 480)  # Height

# Check if the webcam is opened correctly
if not cap.isOpened():
    print("Error: Unable to access webcam.")
    exit()

# Process webcam frames in real-time
while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Unable to capture frame.")
        break

    # Run YOLOv8 inference on the frame
    results = model(frame)

    # Loop through detected objects and draw bounding boxes
    for result in results[0].boxes.data:
        x1, y1, x2, y2, conf, class_id = result.tolist()

        # Get class name
        class_names = model.names
        if int(class_id) in class_names:
            label = class_names[int(class_id)]
            confidence = f"{conf:.2f}"

            # Check if detected object is an animal
            if label in animal_classes:
                color = (0, 255, 0)  # Green for animals
                
                # Draw bounding box and label
                cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), color, 2)
                cv2.putText(frame, f"{label} {confidence}", (int(x1), int(y1) - 5),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    # Display the frame with bounding boxes
    cv2.imshow("YOLO Animal Detection - Live", frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release webcam and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|█████████████████████████████████████████████████████████████████████████████| 6.25M/6.25M [00:02<00:00, 2.32MB/s]
# 0: 480x640 (no detections), 92.0ms
# Speed: 3.4ms preprocess, 92.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 67.6ms
# Speed: 2.2ms preprocess, 67.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 dog, 65.2ms
# Speed: 2.2ms preprocess, 65.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 dog, 66.4ms
# Speed: 1.2ms preprocess, 66.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 64.8ms
# Speed: 2.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.4ms
# Speed: 1.8ms preprocess, 62.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 dog, 64.3ms
# Speed: 1.0ms preprocess, 64.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 dog, 66.2ms
# Speed: 1.0ms preprocess, 66.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 67.7ms
# Speed: 1.2ms preprocess, 67.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.6ms
# Speed: 2.0ms preprocess, 63.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 65.2ms
# Speed: 1.4ms preprocess, 65.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 65.1ms
# Speed: 1.1ms preprocess, 65.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.8ms
# Speed: 1.0ms preprocess, 63.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 68.4ms
# Speed: 1.4ms preprocess, 68.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.5ms
# Speed: 1.3ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 64.0ms
# Speed: 2.6ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 64.7ms
# Speed: 2.3ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.9ms
# Speed: 2.0ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 64.5ms
# Speed: 2.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 64.7ms
# Speed: 1.2ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 dog, 63.4ms
# Speed: 1.0ms preprocess, 63.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 dog, 66.6ms
# Speed: 2.7ms preprocess, 66.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.6ms
# Speed: 2.0ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 64.2ms
# Speed: 1.3ms preprocess, 64.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 64.0ms
# Speed: 1.1ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.9ms
# Speed: 1.0ms preprocess, 63.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 65.1ms
# Speed: 1.1ms preprocess, 65.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.0ms
# Speed: 1.2ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 107.0ms
# Speed: 1.1ms preprocess, 107.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 68.7ms
# Speed: 1.1ms preprocess, 68.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.6ms
# Speed: 1.1ms preprocess, 64.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.2ms
# Speed: 1.1ms preprocess, 56.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.9ms
# Speed: 2.0ms preprocess, 51.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.6ms
# Speed: 1.1ms preprocess, 45.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.7ms
# Speed: 1.0ms preprocess, 46.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.8ms
# Speed: 1.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.7ms
# Speed: 1.5ms preprocess, 46.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 dog, 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 dog, 43.4ms
# Speed: 1.3ms preprocess, 43.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 dog, 43.9ms
# Speed: 1.4ms preprocess, 43.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 41.9ms
# Speed: 1.0ms preprocess, 41.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 44.3ms
# Speed: 2.0ms preprocess, 44.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 40.5ms
# Speed: 1.0ms preprocess, 40.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 40.8ms
# Speed: 1.0ms preprocess, 40.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 45.0ms
# Speed: 1.0ms preprocess, 45.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 44.8ms
# Speed: 2.0ms preprocess, 44.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.1ms
# Speed: 1.0ms preprocess, 42.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 43.1ms
# Speed: 2.0ms preprocess, 43.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 42.8ms
# Speed: 1.0ms preprocess, 42.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 45.5ms
# Speed: 1.0ms preprocess, 45.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 toothbrush, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 toothbrush, 46.2ms
# Speed: 1.0ms preprocess, 46.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.4ms
# Speed: 1.0ms preprocess, 41.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.1ms
# Speed: 1.0ms preprocess, 48.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.6ms
# Speed: 1.0ms preprocess, 48.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 toothbrush, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 toothbrush, 46.0ms
# Speed: 1.0ms preprocess, 46.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.2ms
# Speed: 2.0ms preprocess, 48.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.6ms
# Speed: 1.0ms preprocess, 45.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.0ms
# Speed: 2.4ms preprocess, 45.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.2ms
# Speed: 1.0ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.4ms
# Speed: 1.4ms preprocess, 45.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.0ms
# Speed: 1.1ms preprocess, 43.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.8ms
# Speed: 1.3ms preprocess, 44.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.1ms
# Speed: 1.0ms preprocess, 45.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Speed: 2.6ms preprocess, 43.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.1ms
# Speed: 1.0ms preprocess, 48.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.9ms
# Speed: 1.4ms preprocess, 48.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cats, 47.5ms
# Speed: 1.0ms preprocess, 47.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cats, 48.9ms
# Speed: 1.0ms preprocess, 48.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cats, 50.5ms
# Speed: 1.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 52.6ms
# Speed: 1.3ms preprocess, 52.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 60.2ms
# Speed: 1.0ms preprocess, 60.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 47.0ms
# Speed: 1.0ms preprocess, 47.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.4ms
# Speed: 1.5ms preprocess, 48.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 46.4ms
# Speed: 1.0ms preprocess, 46.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 47.7ms
# Speed: 1.5ms preprocess, 47.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cow, 47.8ms
# Speed: 1.0ms preprocess, 47.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cow, 50.2ms
# Speed: 1.0ms preprocess, 50.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 46.6ms
# Speed: 1.0ms preprocess, 46.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 49.1ms
# Speed: 1.0ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 52.1ms
# Speed: 1.0ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 47.4ms
# Speed: 1.3ms preprocess, 47.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 48.8ms
# Speed: 1.0ms preprocess, 48.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 46.4ms
# Speed: 1.0ms preprocess, 46.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
